# %%
#Análisis estádistico
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import plotly.express as px 
import matplotlib.pyplot as plt
import numpy as np
data=pd.read_csv("/content/drive/MyDrive/TRABAJO/StudentsPerformance.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Writing Score vs Math score (Race/Ethnicity,Gender)
fig= px.scatter(data,x = 'math score', y = 'writing score', color= 'gender',facet_col="race/ethnicity")
fig.update_traces(marker_size = 5)   
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0ff04ae2-1bea-482c-8f73-4a7d7603c89f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ff04ae2-1bea-482c-8f73-4a7d7603c89f")) {                    Plotly.newPlot(                        "0ff04ae2-1bea-482c-8f73-4a7d7603c89f",                        [{"hovertemplate":"gender=female<br>race/ethnicity=group B<br>math score=%{x}<br>writing score=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","symbol":"circle","size":5},"mode":"markers","name":"female","orientation":"v","showlegend":true,"x":[72,90,71,88,38,65,18,65,63,53,47,79,52,70,75,87,59,61,58,68,46,52,62,45,78,57,74,58,52,67,58,65,60,70,37,67,53,73,41,61,24,69,52,61,58,80,50,82,73,90,49,54,66,94,82,54,77,67,40,53,81,48,58,66,67,72,65,50,73,62,77,50,57,59,60,76,74,68,53,62,74,52,49,66,77,76,32,19,48,42,82,60,71,77,23,97,64,63,46,54,58,75,8,65],"xaxis":"x","y":[74,93,78,92,50,73,28,70,61,65,50,92,70,72,82,86,66,87,78,78,58,62,66,55,76,68,76,66,73,83,68,62,70,78,46,82,67,80,51,66,27,74,69,70,59,83,63,77,76,91,54,68,68,92,80,62,94,79,50,70,89,58,65,81,81,79,81,55,79,67,87,66,72,64,74,87,88,80,73,63,72,72,55,70,84,82,44,32,60,51,87,68,82,89,36,96,71,79,55,65,61,80,23,78],"yaxis":"y","type":"scatter"},{"hovertemplate":"gender=female<br>race/ethnicity=group C<br>math score=%{x}<br>writing score=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","symbol":"circle","size":5},"mode":"markers","name":"female","orientation":"v","showlegend":false,"x":[69,69,54,69,67,58,66,71,33,0,69,60,39,73,76,65,58,55,79,88,75,59,59,22,70,96,67,63,43,81,71,46,77,69,67,42,34,55,72,88,64,65,64,44,63,85,65,67,74,68,59,67,71,43,41,82,83,61,72,77,63,46,59,42,52,45,57,65,85,59,54,63,51,82,62,61,67,67,64,65,53,77,84,83,63,68,60,64,83,81,54,86,76,91,36,62,68,47,66,81,62,32,55,63,53,50,65,44,54,92,56,29,85,40,58,65,60,35,44,75,65,50,63,66,69,65,70,29,49,66,49,75,96,76,62,87,81,59,50,77,53,58,62,35,52,52,52,73,54,72,77,48,56,65,74,60,66,59,65,53,71,70,43,62,73,67,52,47,44,57,35,48,54,62,65,64,91,74,40,59],"xaxis":"x2","y":[88,78,61,73,75,68,76,87,43,10,71,74,57,82,88,74,72,65,89,93,84,67,64,33,88,100,70,70,54,87,77,66,87,85,86,60,39,62,71,94,68,81,77,51,81,93,80,81,83,69,75,84,80,53,43,94,95,63,75,95,80,57,70,69,58,70,67,77,95,67,62,68,79,93,62,70,79,77,85,74,62,91,91,90,74,84,74,70,90,90,52,87,85,84,43,70,73,53,83,79,64,33,79,74,56,64,76,62,65,99,72,30,82,54,66,74,72,54,55,85,67,60,71,68,76,84,76,44,53,81,56,90,99,74,70,94,82,72,59,85,64,77,79,43,62,61,57,78,67,83,88,52,70,76,89,74,73,68,81,53,80,76,61,80,74,72,66,66,52,80,46,51,58,69,75,77,94,82,51,65],"yaxis":"y2","type":"scatter"},{"hovertemplate":"gender=female<br>race/ethnicity=group A<br>math score=%{x}<br>writing score=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","symbol":"circle","size":5},"mode":"markers","name":"female","orientation":"v","showlegend":false,"x":[50,55,41,58,51,44,71,38,49,59,47,59,77,65,92,55,48,82,68,65,59,37,72,45,85,61,75,61,50,34,69,56,53,54,78,44],"xaxis":"x3","y":[58,62,48,67,51,58,77,43,55,80,50,69,85,76,97,73,65,93,76,74,70,56,82,64,92,57,79,63,73,41,82,64,60,67,91,45],"yaxis":"y3","type":"scatter"},{"hovertemplate":"gender=female<br>race/ethnicity=group D<br>math score=%{x}<br>writing score=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","symbol":"circle","size":5},"mode":"markers","name":"female","orientation":"v","showlegend":false,"x":[62,69,74,50,75,57,59,58,61,71,73,58,65,85,87,77,51,78,51,76,68,79,97,65,65,56,64,56,71,69,88,47,65,73,70,49,77,56,35,80,27,73,82,59,80,85,62,77,88,52,70,57,47,78,79,26,59,71,55,52,59,74,40,74,66,29,51,82,64,74,63,61,53,81,63,73,69,69,65,54,80,76,74,59,69,85,43,55,69,67,77,79,57,63,42,98,73,52,48,68,46,60,64 ...

# %%
#Writing Score vs Math score (test preparation course,Gender)
fig2= px.scatter(data,x = 'math score', y = 'writing score', color= 'gender',facet_col="test preparation course")
fig2.update_traces(marker_size = 5)  #Cambiar el tamaño del marcador. 
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="53d22a1f-7b39-488b-be28-9875e70fcb33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53d22a1f-7b39-488b-be28-9875e70fcb33")) {                    Plotly.newPlot(                        "53d22a1f-7b39-488b-be28-9875e70fcb33",                        [{"hovertemplate":"gender=female<br>test preparation course=none<br>math score=%{x}<br>writing score=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","symbol":"circle","size":5},"mode":"markers","name":"female","orientation":"v","showlegend":true,"x":[72,90,71,38,65,50,69,18,54,69,67,62,69,63,56,74,50,58,53,50,66,33,0,69,59,60,39,41,62,47,73,76,71,58,73,65,79,58,65,85,58,87,52,70,51,75,78,51,55,87,51,59,76,59,22,81,79,63,46,50,65,77,66,62,45,78,65,57,74,58,42,34,55,45,72,67,80,56,65,71,62,64,70,44,99,63,69,71,47,65,65,73,37,67,65,53,49,73,56,75,71,43,41,82,41,83,61,24,61,72,52,46,59,61,80,58,52,27,44,73,59,80,71,80,38,38,67,64,57,62,77,50,85,49,54,63,82,62,61,47,78,59,73,100,65,53,79,100,71,77,84,26,63,59,55,52,49,60,65,64,83,81,54,54,66,74,40,82,86,74,91,36,29,62,47,51,81,82,64,62,40,32,53,63,53,74,81,53,81,77,63,69,65,55,44,54,48,74,69,65,54,29,76,85,40,61,58,58,65,82,60,37,35,61,75,76,72,59,64,50,73,62,43,55,65,77,66,69,67,49,73,77,49,79,59,57,63,98,76,62,73,53,37,81,50,84,53,48,62,74,68,62,49,66,35,46,77,72,19,52,48,60,42,70,52,87,82,73,64,41,72,45,60,77,78,71,48,65,61,66,39,59,61,87,97,65,53,81,43,59,64,64,51,69,85,50,59,32,73,67,67,69,46,68,44,35,54,48,57,78,58,54,49,74,62,92,45,56,48,100,62,68,75,89,49,54,91,8,74,40,44,55,62,77],"xaxis":"x","y":[74,93,78,50,73,58,78,28,61,73,75,75,74,61,65,83,59,68,65,54,76,43,10,71,59,74,57,48,68,50,82,88,74,67,82,74,92,62,62,89,72,100,70,72,54,82,79,61,65,86,51,67,71,64,33,91,81,70,66,47,70,87,69,66,55,76,77,68,76,66,60,39,62,54,71,83,83,55,62,83,70,68,78,51,90,81,77,70,58,71,80,84,46,82,75,67,52,80,63,79,80,53,43,94,51,95,66,27,63,75,69,57,70,70,89,59,58,32,58,85,73,82,77,83,45,43,75,70,67,64,77,63,95,55,62,68,77,62,70,50,80,69,76,97,74,62,89,100,76,91,91,38,74,61,70,56,54,74,76,70,90,90,68,52,68,82,54,80,87,84,84,43,47,70,53,62,79,89,66,64,50,33,70,74,56,71,89,68,96,80,78,77,76,73,62,65,65,73,73,81,63,30,80,82,54,62,65,66,74,93,72,38,54,62,85,73,79,65,68,55,79,67,58,69,67,87,68,76,74,53,78,73,56,86,70,72,67,99,74,70,84,57,56,82,59,92,64,54,63,72,75,79,55,70,43,57,84,77,32,61,60,70,51,81,57,95,87,78,75,40,83,64,68,88,93,82,52,76,57,73,46,68,63,93,96,81,53,87,61,80,74,71,54,74,85,73,69,38,74,84,72,82,55,66,52,46,65,51,57,96,61,58,60,72,69,100,59,64,53,100,72,67,80,100,61,67,94,23,82,51,45,76,74,86],"yaxis":"y","type":"scatter"},{"hovertemplate":"gender=female<br>test preparation course=completed<br>math score=%{x}<br>writing score=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","symbol":"circle","size":5},"mode":"markers","name":"female","orientation":"v","showlegend":false,"x":[69,88,65,75,55,57,71,82,58,61,63,77,99,79,88,75,42,68,59,70,66,61,75,96,58,68,67,43,81,46,71,52,97,69,67,83,56,52,88,64,58,60,65,64,88,85,59,70,67,74,68,59,77,67,35,69,77,63,42,45,82,85,65,59,88,52,70,51,82,57,47,59,67,67,64,77,83,68,90,71,59,94,95,54,77,76,66,66,67,68,79,66,92,55,74,63,92,61,50,48,73,92,56,44,66,67,80,74,74,65,69,68,85,65,50,63,65,69,50,73,70,29,94,66,75,57,79,59,42,80,60,76,96,74,65,68,87,53,59,77,52,58,52,72,76,52,32,57,54,85,56,69,74,77,60,75,23,40,71,70,71,62,93,86,63,65,34,93,79,52,47,57,65,57,75,65,53,64,78,67,65,88,59,68],"xaxis":"x2","y":[88,92,70,88,62,76,87,86,73,72,70,98,100,89,93,84,54,81,66,88,78,87,85,100,78,78,70,54,87,58,77,62,100,85,86,88,74,73,94,74,68,70,81,77,95,93,75,78,81,83,69,75,91,84,60,74,95,80,69,70,96,100,77,67,100,56,74,79,93,64,67,80,79,77,85,85,90,84,91,83,76,92,92,62,94,85,73,78, ...

# %%
#Reading Score vs Math score (Race/Ethnicity,Gender)
fig3= px.scatter(data,x = 'math score', y = 'reading score', color= 'gender',facet_col="race/ethnicity")
fig3.update_traces(marker_size = 5)   
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b5989c60-f788-4ec8-a7d2-625e2441708a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5989c60-f788-4ec8-a7d2-625e2441708a")) {                    Plotly.newPlot(                        "b5989c60-f788-4ec8-a7d2-625e2441708a",                        [{"hovertemplate":"gender=female<br>race/ethnicity=group B<br>math score=%{x}<br>reading score=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","symbol":"circle","size":5},"mode":"markers","name":"female","orientation":"v","showlegend":true,"x":[72,90,71,88,38,65,18,65,63,53,47,79,52,70,75,87,59,61,58,68,46,52,62,45,78,57,74,58,52,67,58,65,60,70,37,67,53,73,41,61,24,69,52,61,58,80,50,82,73,90,49,54,66,94,82,54,77,67,40,53,81,48,58,66,67,72,65,50,73,62,77,50,57,59,60,76,74,68,53,62,74,52,49,66,77,76,32,19,48,42,82,60,71,77,23,97,64,63,46,54,58,75,8,65],"xaxis":"x","y":[72,95,83,95,60,81,32,75,65,58,49,86,76,64,85,95,70,86,76,83,54,70,64,53,79,69,81,61,66,86,70,64,70,75,46,89,71,76,55,68,38,76,65,72,62,86,67,80,83,90,52,64,69,87,82,61,97,78,48,70,91,56,63,74,80,81,81,53,79,67,85,64,67,63,70,94,90,77,66,62,72,67,58,72,90,85,51,38,62,52,85,72,87,82,44,97,73,78,61,65,68,84,24,82],"yaxis":"y","type":"scatter"},{"hovertemplate":"gender=female<br>race/ethnicity=group C<br>math score=%{x}<br>reading score=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","symbol":"circle","size":5},"mode":"markers","name":"female","orientation":"v","showlegend":false,"x":[69,69,54,69,67,58,66,71,33,0,69,60,39,73,76,65,58,55,79,88,75,59,59,22,70,96,67,63,43,81,71,46,77,69,67,42,34,55,72,88,64,65,64,44,63,85,65,67,74,68,59,67,71,43,41,82,83,61,72,77,63,46,59,42,52,45,57,65,85,59,54,63,51,82,62,61,67,67,64,65,53,77,84,83,63,68,60,64,83,81,54,86,76,91,36,62,68,47,66,81,62,32,55,63,53,50,65,44,54,92,56,29,85,40,58,65,60,35,44,75,65,50,63,66,69,65,70,29,49,66,49,75,96,76,62,87,81,59,50,77,53,58,62,35,52,52,52,73,54,72,77,48,56,65,74,60,66,59,65,53,71,70,43,62,73,67,52,47,44,57,35,48,54,62,65,64,91,74,40,59],"xaxis":"x2","y":[90,75,58,73,69,73,71,84,41,17,80,72,64,80,83,72,67,69,92,93,81,66,62,39,89,100,75,67,51,91,77,64,88,84,84,62,42,65,72,95,73,81,79,50,75,92,86,84,75,67,64,79,81,53,46,90,93,73,80,94,78,58,71,66,58,73,78,74,89,54,59,73,72,93,67,72,81,74,85,77,61,90,87,85,69,86,75,64,83,88,48,92,87,86,53,74,67,54,83,77,67,39,72,74,62,66,76,63,64,100,79,29,84,58,59,77,68,61,51,88,69,60,73,76,78,84,82,40,53,74,63,82,96,76,72,89,84,73,60,90,72,75,78,44,59,65,55,76,64,80,91,58,68,69,86,64,77,72,79,62,71,72,62,76,78,75,61,62,61,77,53,56,61,69,76,82,95,75,59,71],"yaxis":"y2","type":"scatter"},{"hovertemplate":"gender=female<br>race/ethnicity=group A<br>math score=%{x}<br>reading score=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","symbol":"circle","size":5},"mode":"markers","name":"female","orientation":"v","showlegend":false,"x":[50,55,41,58,51,44,71,38,49,59,47,59,77,65,92,55,48,82,68,65,59,37,72,45,85,61,75,61,50,34,69,56,53,54,78,44],"xaxis":"x3","y":[53,65,51,70,49,64,83,43,65,85,59,73,88,85,100,73,66,93,80,70,72,57,79,59,90,60,82,68,67,48,84,58,50,63,87,45],"yaxis":"y3","type":"scatter"},{"hovertemplate":"gender=female<br>race/ethnicity=group D<br>math score=%{x}<br>reading score=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","symbol":"circle","size":5},"mode":"markers","name":"female","orientation":"v","showlegend":false,"x":[62,69,74,50,75,57,59,58,61,71,73,58,65,85,87,77,51,78,51,76,68,79,97,65,65,56,64,56,71,69,88,47,65,73,70,49,77,56,35,80,27,73,82,59,80,85,62,77,88,52,70,57,47,78,79,26,59,71,55,52,59,74,40,74,66,29,51,82,64,74,63,61,53,81,63,73,69,69,65,54,80,76,74,59,69,85,43,55,69,67,77,79,57,63,42,98,73,52,48,68,46,60, ...

# %%
#Reading Score vs Math score (test preparation course,Gender)
fig4= px.scatter(data,x = 'math score', y = 'reading score', color= 'gender',facet_col="test preparation course")
fig4.update_traces(marker_size = 5)  #Cambiar el tamaño del marcador. 
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="da0851bf-8e43-4cc7-b782-59f211ca6541" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da0851bf-8e43-4cc7-b782-59f211ca6541")) {                    Plotly.newPlot(                        "da0851bf-8e43-4cc7-b782-59f211ca6541",                        [{"hovertemplate":"gender=female<br>test preparation course=none<br>math score=%{x}<br>writing score=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","symbol":"circle","size":5},"mode":"markers","name":"female","orientation":"v","showlegend":true,"x":[72,90,71,38,65,50,69,18,54,69,67,62,69,63,56,74,50,58,53,50,66,33,0,69,59,60,39,41,62,47,73,76,71,58,73,65,79,58,65,85,58,87,52,70,51,75,78,51,55,87,51,59,76,59,22,81,79,63,46,50,65,77,66,62,45,78,65,57,74,58,42,34,55,45,72,67,80,56,65,71,62,64,70,44,99,63,69,71,47,65,65,73,37,67,65,53,49,73,56,75,71,43,41,82,41,83,61,24,61,72,52,46,59,61,80,58,52,27,44,73,59,80,71,80,38,38,67,64,57,62,77,50,85,49,54,63,82,62,61,47,78,59,73,100,65,53,79,100,71,77,84,26,63,59,55,52,49,60,65,64,83,81,54,54,66,74,40,82,86,74,91,36,29,62,47,51,81,82,64,62,40,32,53,63,53,74,81,53,81,77,63,69,65,55,44,54,48,74,69,65,54,29,76,85,40,61,58,58,65,82,60,37,35,61,75,76,72,59,64,50,73,62,43,55,65,77,66,69,67,49,73,77,49,79,59,57,63,98,76,62,73,53,37,81,50,84,53,48,62,74,68,62,49,66,35,46,77,72,19,52,48,60,42,70,52,87,82,73,64,41,72,45,60,77,78,71,48,65,61,66,39,59,61,87,97,65,53,81,43,59,64,64,51,69,85,50,59,32,73,67,67,69,46,68,44,35,54,48,57,78,58,54,49,74,62,92,45,56,48,100,62,68,75,89,49,54,91,8,74,40,44,55,62,77],"xaxis":"x","y":[74,93,78,50,73,58,78,28,61,73,75,75,74,61,65,83,59,68,65,54,76,43,10,71,59,74,57,48,68,50,82,88,74,67,82,74,92,62,62,89,72,100,70,72,54,82,79,61,65,86,51,67,71,64,33,91,81,70,66,47,70,87,69,66,55,76,77,68,76,66,60,39,62,54,71,83,83,55,62,83,70,68,78,51,90,81,77,70,58,71,80,84,46,82,75,67,52,80,63,79,80,53,43,94,51,95,66,27,63,75,69,57,70,70,89,59,58,32,58,85,73,82,77,83,45,43,75,70,67,64,77,63,95,55,62,68,77,62,70,50,80,69,76,97,74,62,89,100,76,91,91,38,74,61,70,56,54,74,76,70,90,90,68,52,68,82,54,80,87,84,84,43,47,70,53,62,79,89,66,64,50,33,70,74,56,71,89,68,96,80,78,77,76,73,62,65,65,73,73,81,63,30,80,82,54,62,65,66,74,93,72,38,54,62,85,73,79,65,68,55,79,67,58,69,67,87,68,76,74,53,78,73,56,86,70,72,67,99,74,70,84,57,56,82,59,92,64,54,63,72,75,79,55,70,43,57,84,77,32,61,60,70,51,81,57,95,87,78,75,40,83,64,68,88,93,82,52,76,57,73,46,68,63,93,96,81,53,87,61,80,74,71,54,74,85,73,69,38,74,84,72,82,55,66,52,46,65,51,57,96,61,58,60,72,69,100,59,64,53,100,72,67,80,100,61,67,94,23,82,51,45,76,74,86],"yaxis":"y","type":"scatter"},{"hovertemplate":"gender=female<br>test preparation course=completed<br>math score=%{x}<br>writing score=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","symbol":"circle","size":5},"mode":"markers","name":"female","orientation":"v","showlegend":false,"x":[69,88,65,75,55,57,71,82,58,61,63,77,99,79,88,75,42,68,59,70,66,61,75,96,58,68,67,43,81,46,71,52,97,69,67,83,56,52,88,64,58,60,65,64,88,85,59,70,67,74,68,59,77,67,35,69,77,63,42,45,82,85,65,59,88,52,70,51,82,57,47,59,67,67,64,77,83,68,90,71,59,94,95,54,77,76,66,66,67,68,79,66,92,55,74,63,92,61,50,48,73,92,56,44,66,67,80,74,74,65,69,68,85,65,50,63,65,69,50,73,70,29,94,66,75,57,79,59,42,80,60,76,96,74,65,68,87,53,59,77,52,58,52,72,76,52,32,57,54,85,56,69,74,77,60,75,23,40,71,70,71,62,93,86,63,65,34,93,79,52,47,57,65,57,75,65,53,64,78,67,65,88,59,68],"xaxis":"x2","y":[88,92,70,88,62,76,87,86,73,72,70,98,100,89,93,84,54,81,66,88,78,87,85,100,78,78,70,54,87,58,77,62,100,85,86,88,74,73,94,74,68,70,81,77,95,93,75,78,81,83,69,75,91,84,60,74,95,80,69,70,96,100,77,67,100,56,74,79,93,64,67,80,79,77,85,85,90,84,91,83,76,92,92,62,94,85,73,78, ...

# %%
#Writing Score vs Reading score (Race/Ethnicity,Gender)
fig5= px.scatter(data,x = 'reading score', y = 'writing score', color= 'gender',facet_col="race/ethnicity")
fig5.update_traces(marker_size = 5)   
fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f3c59c62-e282-4045-90f7-2e6b0821b857" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3c59c62-e282-4045-90f7-2e6b0821b857")) {                    Plotly.newPlot(                        "f3c59c62-e282-4045-90f7-2e6b0821b857",                        [{"hovertemplate":"gender=female<br>race/ethnicity=group B<br>reading score=%{x}<br>writing score=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","symbol":"circle","size":5},"mode":"markers","name":"female","orientation":"v","showlegend":true,"x":[72,95,83,95,60,81,32,75,65,58,49,86,76,64,85,95,70,86,76,83,54,70,64,53,79,69,81,61,66,86,70,64,70,75,46,89,71,76,55,68,38,76,65,72,62,86,67,80,83,90,52,64,69,87,82,61,97,78,48,70,91,56,63,74,80,81,81,53,79,67,85,64,67,63,70,94,90,77,66,62,72,67,58,72,90,85,51,38,62,52,85,72,87,82,44,97,73,78,61,65,68,84,24,82],"xaxis":"x","y":[74,93,78,92,50,73,28,70,61,65,50,92,70,72,82,86,66,87,78,78,58,62,66,55,76,68,76,66,73,83,68,62,70,78,46,82,67,80,51,66,27,74,69,70,59,83,63,77,76,91,54,68,68,92,80,62,94,79,50,70,89,58,65,81,81,79,81,55,79,67,87,66,72,64,74,87,88,80,73,63,72,72,55,70,84,82,44,32,60,51,87,68,82,89,36,96,71,79,55,65,61,80,23,78],"yaxis":"y","type":"scatter"},{"hovertemplate":"gender=female<br>race/ethnicity=group C<br>reading score=%{x}<br>writing score=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","symbol":"circle","size":5},"mode":"markers","name":"female","orientation":"v","showlegend":false,"x":[90,75,58,73,69,73,71,84,41,17,80,72,64,80,83,72,67,69,92,93,81,66,62,39,89,100,75,67,51,91,77,64,88,84,84,62,42,65,72,95,73,81,79,50,75,92,86,84,75,67,64,79,81,53,46,90,93,73,80,94,78,58,71,66,58,73,78,74,89,54,59,73,72,93,67,72,81,74,85,77,61,90,87,85,69,86,75,64,83,88,48,92,87,86,53,74,67,54,83,77,67,39,72,74,62,66,76,63,64,100,79,29,84,58,59,77,68,61,51,88,69,60,73,76,78,84,82,40,53,74,63,82,96,76,72,89,84,73,60,90,72,75,78,44,59,65,55,76,64,80,91,58,68,69,86,64,77,72,79,62,71,72,62,76,78,75,61,62,61,77,53,56,61,69,76,82,95,75,59,71],"xaxis":"x2","y":[88,78,61,73,75,68,76,87,43,10,71,74,57,82,88,74,72,65,89,93,84,67,64,33,88,100,70,70,54,87,77,66,87,85,86,60,39,62,71,94,68,81,77,51,81,93,80,81,83,69,75,84,80,53,43,94,95,63,75,95,80,57,70,69,58,70,67,77,95,67,62,68,79,93,62,70,79,77,85,74,62,91,91,90,74,84,74,70,90,90,52,87,85,84,43,70,73,53,83,79,64,33,79,74,56,64,76,62,65,99,72,30,82,54,66,74,72,54,55,85,67,60,71,68,76,84,76,44,53,81,56,90,99,74,70,94,82,72,59,85,64,77,79,43,62,61,57,78,67,83,88,52,70,76,89,74,73,68,81,53,80,76,61,80,74,72,66,66,52,80,46,51,58,69,75,77,94,82,51,65],"yaxis":"y2","type":"scatter"},{"hovertemplate":"gender=female<br>race/ethnicity=group A<br>reading score=%{x}<br>writing score=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","symbol":"circle","size":5},"mode":"markers","name":"female","orientation":"v","showlegend":false,"x":[53,65,51,70,49,64,83,43,65,85,59,73,88,85,100,73,66,93,80,70,72,57,79,59,90,60,82,68,67,48,84,58,50,63,87,45],"xaxis":"x3","y":[58,62,48,67,51,58,77,43,55,80,50,69,85,76,97,73,65,93,76,74,70,56,82,64,92,57,79,63,73,41,82,64,60,67,91,45],"yaxis":"y3","type":"scatter"},{"hovertemplate":"gender=female<br>race/ethnicity=group D<br>reading score=%{x}<br>writing score=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","symbol":"circle","size":5},"mode":"markers","name":"female","orientation":"v","showlegend":false,"x":[70,74,81,64,90,74,58,63,74,71,86,67,67,91,100,89,58,82,63,72,75,86,100,69,81,68,60,52,83,72,92,53,70,79,78,57,82,65,55,90,34,84,97,70,90,95,64,68,99,57,71,58,58,81,89,31,67,76,64,59,78,79,59,89,78,41,66,95,63,75,80,71,61,97,73,75,77,77,82,60,92,74,88,70,79,86,60,71,77,72,77,89,78,64,61,100, ...

# %%
#Writing Score vs Reading score (test preparation course,Gender)
fig6= px.scatter(data,x = 'reading score', y = 'writing score', color= 'gender',facet_col="test preparation course")
fig6.update_traces(marker_size = 5)  #Cambiar el tamaño del marcador. 
fig6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="80ca3ca4-9535-4417-b0c5-e575bfdc35a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80ca3ca4-9535-4417-b0c5-e575bfdc35a3")) {                    Plotly.newPlot(                        "80ca3ca4-9535-4417-b0c5-e575bfdc35a3",                        [{"hovertemplate":"gender=female<br>test preparation course=none<br>reading score=%{x}<br>writing score=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","symbol":"circle","size":5},"mode":"markers","name":"female","orientation":"v","showlegend":true,"x":[72,95,83,60,81,53,75,32,58,73,69,70,74,65,72,81,64,73,58,56,71,41,17,80,58,72,64,51,68,49,80,83,71,70,86,72,86,67,67,91,67,100,76,64,58,85,82,63,69,95,49,66,72,62,39,92,86,67,64,50,69,88,65,64,53,79,81,69,81,61,62,42,65,56,72,86,83,52,64,83,73,73,75,50,93,75,72,76,53,70,86,79,46,89,73,71,57,76,65,86,81,53,46,90,55,93,68,38,73,80,65,58,71,72,90,62,58,34,64,84,70,90,83,86,49,43,76,73,78,64,68,67,89,65,59,73,80,67,72,59,81,73,83,92,77,61,89,100,70,90,87,31,69,67,64,59,52,75,85,64,83,88,64,48,69,79,59,82,92,89,86,53,41,74,54,66,77,95,63,67,48,39,70,74,62,81,91,61,97,79,73,77,76,73,63,64,66,76,77,82,60,29,78,84,58,64,63,59,77,93,68,45,61,58,88,74,81,70,62,53,79,67,60,71,69,85,76,78,72,53,76,77,63,89,72,67,64,100,76,72,92,58,57,84,60,95,72,58,62,72,71,78,58,72,44,56,90,79,38,65,62,66,52,84,55,94,85,76,74,45,80,59,72,91,90,87,58,69,60,77,52,72,68,85,97,79,62,86,62,72,76,73,51,65,92,67,62,34,78,84,75,84,61,70,61,53,65,56,58,91,68,61,58,74,69,100,63,58,54,100,70,76,84,100,65,63,95,24,75,59,45,76,72,86],"xaxis":"x","y":[74,93,78,50,73,58,78,28,61,73,75,75,74,61,65,83,59,68,65,54,76,43,10,71,59,74,57,48,68,50,82,88,74,67,82,74,92,62,62,89,72,100,70,72,54,82,79,61,65,86,51,67,71,64,33,91,81,70,66,47,70,87,69,66,55,76,77,68,76,66,60,39,62,54,71,83,83,55,62,83,70,68,78,51,90,81,77,70,58,71,80,84,46,82,75,67,52,80,63,79,80,53,43,94,51,95,66,27,63,75,69,57,70,70,89,59,58,32,58,85,73,82,77,83,45,43,75,70,67,64,77,63,95,55,62,68,77,62,70,50,80,69,76,97,74,62,89,100,76,91,91,38,74,61,70,56,54,74,76,70,90,90,68,52,68,82,54,80,87,84,84,43,47,70,53,62,79,89,66,64,50,33,70,74,56,71,89,68,96,80,78,77,76,73,62,65,65,73,73,81,63,30,80,82,54,62,65,66,74,93,72,38,54,62,85,73,79,65,68,55,79,67,58,69,67,87,68,76,74,53,78,73,56,86,70,72,67,99,74,70,84,57,56,82,59,92,64,54,63,72,75,79,55,70,43,57,84,77,32,61,60,70,51,81,57,95,87,78,75,40,83,64,68,88,93,82,52,76,57,73,46,68,63,93,96,81,53,87,61,80,74,71,54,74,85,73,69,38,74,84,72,82,55,66,52,46,65,51,57,96,61,58,60,72,69,100,59,64,53,100,72,67,80,100,61,67,94,23,82,51,45,76,74,86],"yaxis":"y","type":"scatter"},{"hovertemplate":"gender=female<br>test preparation course=completed<br>reading score=%{x}<br>writing score=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","symbol":"circle","size":5},"mode":"markers","name":"female","orientation":"v","showlegend":false,"x":[90,95,75,90,65,74,84,85,63,74,72,89,100,92,93,81,55,75,70,89,74,86,88,100,76,83,75,51,91,54,77,70,100,84,84,86,68,66,95,60,70,70,81,79,92,92,63,78,84,75,67,64,82,79,55,76,94,78,66,73,97,95,74,54,99,57,71,72,93,58,58,85,81,74,85,88,85,86,90,76,78,87,89,61,97,87,74,78,78,67,88,83,100,72,75,80,100,71,66,56,75,100,79,51,74,80,92,88,79,81,79,80,86,70,60,73,84,77,64,78,82,40,99,74,82,78,81,63,61,85,70,94,96,90,75,77,89,66,73,90,59,75,67,79,85,59,51,68,64,90,68,86,86,82,64,82,44,65,71,72,70,76,100,85,78,78,48,100,84,61,62,77,61,75,77,76,50,82,87,86,82,99,71,78],"xaxis":"x2","y":[88,92,70,88,62,76,87,86,73,72,70,98,100,89,93,84,54,81,66,88,78,87,85,100,78,78,70,54,87,58,77,62,100,85,86,88,74,73,94,74,68,70,81,77,95,93,75,78,81,83,69,75,91,84,60,74,95,80,69,70,96,100,77,67,100,56,74,79,93,64,67,80,79,77,85,85,90,84,91,83,76,92 ...

# %%
#Modelo 1: Regresión lineal:
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split as tts
df_students = data
# print(df_students)

x_gender_ = np.array(df_students['gender'])
x_race_ = np.array(df_students['race/ethnicity'])
x_course_ = np.array(df_students['test preparation course'])
x_reading = np.array(df_students['reading score'])
x_writing = np.array(df_students['writing score'])

label_encoder = LabelEncoder()
x_gender = label_encoder.fit_transform(x_gender_)
x_race = label_encoder.fit_transform(x_race_)
x_course = label_encoder.fit_transform(x_course_)

x = np.c_[x_gender, x_race, x_course, x_reading, x_writing]
y = np.array(df_students['math score'])

xtrain, xtest, ytrain, ytest = tts(x, y, test_size = 0.20, random_state = 42)

linear_model = LinearRegression()
linear_model.fit(xtrain, ytrain)

y_pr_train, y_pr_test = linear_model.predict(xtrain), linear_model.predict(xtest)
    
score_total_train = linear_model.score(xtrain, ytrain)
score_total_validation = linear_model.score(xtest, ytest)
print("El score en entrenamiento es ", round(score_total_train, 4))
print("El score en validación es ", round(score_total_validation, 4))

X_genero_ = int(input('Ingrese el género (male = 1/female = 0): '))
X_raza_ = int(input('Ingrese el grupo de raza/etnia (A = 0/B = 1/C = 2/D = 3): '))
X_curso_ = int(input('Ingrese si completó curso de preparación (none = 1/completed = 0): '))
X_lectura = float(input('Ingrese el puntaje de lectura: '))
X_escritura = float(input('Ingrese el puntaje de escritura: '))

Xpre = [[X_genero_, X_raza_, X_curso_, X_lectura, X_escritura]]

prediccion = linear_model.predict(Xpre)
print('La predicción de Math Score es:', int(prediccion))
# Out:
# El score en entrenamiento es  0.8483
# El score en validación es  0.8789
# Ingrese el género (male = 1/female = 0): 0
# Ingrese el grupo de raza/etnia (A = 0/B = 1/C = 2/D = 3): 2
# Ingrese si completó curso de preparación (none = 1/completed = 0): 1
# Ingrese el puntaje de lectura: 88
# Ingrese el puntaje de escritura: 90
# La predicción de Math Score es: 81

# %%
#Modelo 2:Ridge:
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split as tts
x_gender_ = np.array(df_students['gender'])
x_race_ = np.array(df_students['race/ethnicity'])
x_course_ = np.array(df_students['test preparation course'])
x_reading = np.array(df_students['reading score'])
x_writing = np.array(df_students['writing score'])

label_encoder = LabelEncoder()
x_gender = label_encoder.fit_transform(x_gender_)
x_race = label_encoder.fit_transform(x_race_)
x_course = label_encoder.fit_transform(x_course_)

x = np.c_[x_gender, x_race, x_course, x_reading, x_writing]
y = np.array(df_students['math score'])

xtrain, xtest, ytrain, ytest = tts(x, y, test_size = 0.20, random_state = 42)

linear_model = Ridge()
linear_model.fit(xtrain, ytrain)

y_pr_train, y_pr_test = linear_model.predict(xtrain), linear_model.predict(xtest)

    
score_total_train = linear_model.score(xtrain, ytrain)
score_total_validation = linear_model.score(xtest, ytest)
print("El score en entrenamiento es ", round(score_total_train, 4))
print("El score en validación es ", round(score_total_validation, 4))

X_genero_ = int(input('Ingrese el género (male = 1/female = 0): '))
X_raza_ = int(input('Ingrese el grupo de raza/etnia (A = 0/B = 1/C = 2/D = 3): '))
X_curso_ = int(input('Ingrese si completó curso de preparación (none = 1/completed = 0): '))
X_lectura = float(input('Ingrese el puntaje de lectura: '))
X_escritura = float(input('Ingrese el puntaje de escritura: '))

Xpre = [[X_genero_, X_raza_, X_curso_, X_lectura, X_escritura]]

prediccion = linear_model.predict(Xpre)
print('La predicción de Math Score es:', int(prediccion))
# Out:
# El score en entrenamiento es  0.8483230531179223
# El score en validación es  0.8788559576676997

# %%
#Modelo 3: Random Forest Regressor:
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split as tts
x_gender_ = np.array(df_students['gender'])
x_race_ = np.array(df_students['race/ethnicity'])
x_course_ = np.array(df_students['test preparation course'])
x_reading = np.array(df_students['reading score'])
x_writing = np.array(df_students['writing score'])

label_encoder = LabelEncoder()
x_gender = label_encoder.fit_transform(x_gender_)
x_race = label_encoder.fit_transform(x_race_)
x_course = label_encoder.fit_transform(x_course_)

x = np.c_[x_gender, x_race, x_course, x_reading, x_writing]
y = np.array(df_students['math score'])

xtrain, xtest, ytrain, ytest = tts(x, y, test_size = 0.20, random_state = 42)

RFR_model = RandomForestRegressor(random_state=42)
RFR_model.fit(xtrain, ytrain)

y_pr_train, y_pr_test = RFR_model.predict(xtrain), RFR_model.predict(xtest)
    
score_total_train = RFR_model.score(xtrain, ytrain)
score_total_validation = RFR_model.score(xtest, ytest)
print("El score en entrenamiento es ", round(score_total_train, 4))
print("El score en validación es ", round(score_total_validation, 4))

X_genero_ = int(input('Ingrese el género (male = 1/female = 0): '))
X_raza_ = int(input('Ingrese el grupo de raza/etnia (A = 0/B = 1/C = 2/D = 3): '))
X_curso_ = int(input('Ingrese si completó curso de preparación (none = 1/completed = 0): '))
X_lectura = float(input('Ingrese el puntaje de lectura: '))
X_escritura = float(input('Ingrese el puntaje de escritura: '))

Xpre = [[X_genero_, X_raza_, X_curso_, X_lectura, X_escritura]]

prediccion = linear_model.predict(Xpre)
print('La predicción de Math Score es:', int(prediccion))
# Out:
# El score en entrenamiento es  0.9726
# El score en validación es  0.8396
# Ingrese el género (male = 1/female = 0): 1
# Ingrese el grupo de raza/etnia (A = 0/B = 1/C = 2/D = 3): 2
# Ingrese si completó curso de preparación (none = 1/completed = 0): 0
# Ingrese el puntaje de lectura: 88
# Ingrese el puntaje de escritura: 90
# La predicción de Math Score es: 91

# %%
#Modelo 4: GradientBoostinRegressor:
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split as tts
from sklearn.ensemble import GradientBoostingRegressor

x_gender_ = np.array(df_students['gender'])
x_race_ = np.array(df_students['race/ethnicity'])
x_course_ = np.array(df_students['test preparation course'])
x_reading = np.array(df_students['reading score'])
x_writing = np.array(df_students['writing score'])

label_encoder = LabelEncoder()
x_gender = label_encoder.fit_transform(x_gender_)
x_race = label_encoder.fit_transform(x_race_)
x_course = label_encoder.fit_transform(x_course_)

x = np.c_[x_gender, x_race, x_course, x_reading, x_writing]
y = np.array(df_students['math score'])

xtrain, xtest, ytrain, ytest = tts(x, y, test_size = 0.20, random_state = 42)

RFR_model = GradientBoostingRegressor(random_state=42, max_depth=4)
RFR_model.fit(xtrain, ytrain)

y_pr_train, y_pr_test = RFR_model.predict(xtrain), RFR_model.predict(xtest)
    
score_total_train = RFR_model.score(xtrain, ytrain)
score_total_validation = RFR_model.score(xtest, ytest)
print("El score en entrenamiento es ", round(score_total_train, 4))
print("El score en validación es ", round(score_total_validation, 4))

X_genero_ = int(input('Ingrese el género (male = 1/female = 0): '))
X_raza_ = int(input('Ingrese el grupo de raza/etnia (A = 0/B = 1/C = 2/D = 3): '))
X_curso_ = int(input('Ingrese si completó curso de preparación (none = 1/completed = 0): '))
X_lectura = float(input('Ingrese el puntaje de lectura: '))
X_escritura = float(input('Ingrese el puntaje de escritura: '))

Xpre = [[X_genero_, X_raza_, X_curso_, X_lectura, X_escritura]]

prediccion = linear_model.predict(Xpre)
print('La predicción de Math Score es:', int(prediccion))
# Out:
# El score en entrenamiento es  0.9146408569940696
# El score en validación es  0.871899046468426
